 2159, 2122, 3169], [3820, 1514, 1537, 1678, 1568, 1563, 1891, 1808, 2662], [4536, 1646, 1554, 1728, 1612, 1741, 1953, 1782, 2957], [706, 329, 278, 220, 157, 196, 176, 164, 222], [11, 8, 9, 7, 7, 6, 7, 8, 8], [3319, 779, 853, 841, 754, 905, 1071, 975, 1852], [2639, 466, 524, 590, 590, 655, 814, 666, 1408]], '03032019': [[1252, 1341, 1407, 1311, 1343, 1322, 1357, 1367, 1373], [976, 1110, 1099, 1095, 1137, 1110, 1152, 1138, 1153], [834, 1027, 1012, 1060, 1131, 1087, 1128, 1155, 1098], [626, 881, 879, 917, 988, 1013, 1068, 1073, 849], [707, 937, 1030, 862, 934, 976, 1016, 1001, 765], [892, 897, 1071, 853, 776, 828, 875, 837, 770], [965, 991, 1201, 869, 827, 851, 927, 898, 772], [750, 877, 784, 734, 668, 709, 798, 733, 709], [1071, 962, 1168, 787, 673, 740, 764, 755, 688], [529, 571, 543, 417, 286, 294, 282, 350, 277], [10, 13, 12, 10, 9, 10, 10, 8, 11], [807, 728, 940, 608, 258, 292, 294, 336, 300], [408, 494, 622, 356, 140, 180, 188, 178, 152]]}
#json.dump(dict_data, open("result.txt",'w'))

dict_data = json.load(open("result_sen2cor.txt"))
dict_data['18032017']
# Out:
# [[1767, 742, 720, 785, 844, 667, 902, 841, 961],
#  [1818, 907, 842, 1079, 1233, 1082, 1281, 1081, 1329],
#  [1725, 865, 821, 1099, 1300, 1345, 1654, 1219, 1601],
#  [2940, 923, 777, 1128, 716, 1068, 1688, 1130, 1411]]

# %%
# real date is the date of measuring tss
realdate=['08032017', '08052017', '23072017', '22082017', '28102017', 
          '15032018', '20052018', '25072018', '21082018', '27102018', '09032019']
# ref date is the date of taking value from sentinel2
refdate=['18032017', '17052017', '16072017', '20082017', '24102017', 
         '13032018', '22052018', '11072018', '20082018', '19102018', '03032019']

imgName = ['T48QUJ_20170318T033531_B','T48QUJ_20170517T033541_B','T48QUJ_20170716T033541_B','T48QUJ_20171024T033821_B','T48QUJ_20180313T033531_B',
           'T48QUJ_20180522T033541_B','T48QUJ_20180711T033541_B','T48QUJ_20180820T033531_B','T48QUJ_20181019T033741_B','T48QUJ_20170820T033529_B','T48QUJ_20190303T033639_B']

# get sentinel data by placeIndex and dateIndex
def getBandData(placeIdx, dateIdx):
    date = refdate[dateIdx]
    data = []
    for d in dict_data[date]:
        data.append(d[placeIdx])
    return data

print(getBandData(1, 0))

print("TSS_Date", "Sentinel2_Date", "Image_Name")
for i in range(len(realdate)):
    print(realdate[i], refdate[i], imgName[i])
# Out:
# [742, 907, 865, 923]
# TSS_Date Sentinel2_Date Image_Name
# 08032017 18032017 T48QUJ_20170318T033531_B
# 08052017 17052017 T48QUJ_20170517T033541_B
# 23072017 16072017 T48QUJ_20170716T033541_B
# 22082017 20082017 T48QUJ_20171024T033821_B
# 28102017 24102017 T48QUJ_20180313T033531_B
# 15032018 13032018 T48QUJ_20180522T033541_B
# 20052018 22052018 T48QUJ_20180711T033541_B
# 25072018 11072018 T48QUJ_20180820T033531_B
# 21082018 20082018 T48QUJ_20181019T033741_B
# 27102018 19102018 T48QUJ_20170820T033529_B
# 09032019 03032019 T48QUJ_20190303T033639_B

# %%
dataByDate = [] 
for d in range(len(refdate)):
    for p in range(len(listCoord)):
        dataByDate.append(getBandData(p, d))
dataByDate = np.array(dataByDate)
dataByDate.shape
# Out:
# (99, 4)

# %%
dataByDate # [idx, band]
# Out:
# array([[ 1767,  1818,  1725,  2940],
#        [  742,   907,   865,   923],
#        [  720,   842,   821,   777],
#        [  785,  1079,  1099,  1128],
#        [  844,  1233,  1300,   716],
#        [  667,  1082,  1345,  1068],
#        [  902,  1281,  1654,  1688],
#        [  841,  1081,  1219,  1130],
#        [  961,  1329,  1601,  1411],
#        [ 8007,  8199,  8191,  8552],
#        [ 8504,  8808,  8847,  9148],
#        [ 7957,  8169,  8219,  8469],
#        [ 6703,  6837,  6834,  7154],
#        [ 6852,  6986,  6977,  7274],
#        [ 6915,  7032,  7028,  7341],
#        [ 7013,  7156,  7086,  7475],
#        [ 6847,  7014,  7044,  7310],
#        [ 7819,  8005,  8012,  8252],
#        [  890,  1384,  1410,  2847],
#        [ 1292,  1881,  2154,  1835],
#        [ 4202,  4543,  4589,  5296],
#        [ 7716,  7342,  6981,  7318],
#        [ 1201,  1507,  1624,  1281],
#        [ 1988,  2513,  2817,  2613],
#        [ 5292,  5077,  4799,  5106],
# ...

# %%
# "Observation-TSS-data_24Jun2019.xlsx"
import pandas as pd
df = pd.read_excel ('Processed data_6Mar2020.xlsx', sheet_name='New Data_TSS',skiprows=0)
df = df.drop(columns=['Y (m)', 'X (m)', 'ID'])
df
# Out:
#      Date's Observation            Sentinel2_Code  Date Image  Observed TSS  \
# 0            17/03/2017  T48QUJ_20170318T033531_B    18032017       278.558
# 1            17/03/2017  T48QUJ_20170318T033531_B    18032017       128.603
# 2            17/03/2017  T48QUJ_20170318T033531_B    18032017       128.136
# 3            17/03/2017  T48QUJ_20170318T033531_B    18032017       116.209
# 4            17/03/2017  T48QUJ_20170318T033531_B    18032017        95.614
# ..                  ...                       ...         ...           ...
# 94  2019-03-03 00:00:00  T48QUJ_20190303T033639_B     3032019        79.000
# 95  2019-03-03 00:00:00  T48QUJ_20190303T033639_B     3032019        64.000
# 96  2019-03-03 00:00:00  T48QUJ_20190303T033639_B     3032019       140.000
# 97  2019-03-03 00:00:00  T48QUJ_20190303T033639_B     3032019        76.000
# 98  2019-03-03 00:00:00  T48QUJ_20190303T033639_B     3032019        81.000
#
# ...

# %%
df.head(5)
# Out:
#   Date's Observation            Sentinel2_Code  Date Image  Observed TSS  \
# 0         17/03/2017  T48QUJ_20170318T033531_B    18032017       278.558
# 1         17/03/2017  T48QUJ_20170318T033531_B    18032017       128.603
# 2         17/03/2017  T48QUJ_20170318T033531_B    18032017       128.136
# 3         17/03/2017  T48QUJ_20170318T033531_B    18032017       116.209
# 4         17/03/2017  T48QUJ_20170318T033531_B    18032017        95.614
#
#    Band1  Band2  Band3  Band4  Band5  Band6  Band7  Band8  Band8A  Band9  \
# 0   2508   1856   1673   1584   1801   2399   2730   2570    2976    854
# 1   1544   1261   1111    970   1055   1391   1597   1036    1643    311
# 2   1550   1235   1053    924    904   1051   1129    886    1045    208
# 3   1472   1262   1195   1122   1117   1467   1679   1180    1732    280
# 4   1524   1305   1300   1272   1186   1130   1233    862    1118    261
#
#    Band10  Band11  Band12
# 0      13    2316    1475
# 1       9    1125     647
# ...

# %%
df_filtered = df[["Date's Observation", "Sentinel2_Code", "Date Image", "Observed TSS"]]
df_filtered.head(5)
# Out:
#   Date's Observation            Sentinel2_Code  Date Image  Observed TSS
# 0         17/03/2017  T48QUJ_20170318T033531_B    18032017       278.558
# 1         17/03/2017  T48QUJ_20170318T033531_B    18032017       128.603
# 2         17/03/2017  T48QUJ_20170318T033531_B    18032017       128.136
# 3         17/03/2017  T48QUJ_20170318T033531_B    18032017       116.209
# 4         17/03/2017  T48QUJ_20170318T033531_B    18032017        95.614

# %%
df_filtered['Band2'] = dataByDate[:,0]
df_filtered['Band3'] = dataByDate[:,1]
df_filtered['Band4'] = dataByDate[:,2]
df_filtered['Band8'] = dataByDate[:,3]

"""
for i in range(13):
    if i < 8:
        df_filtered['band'+str(i)] = dataByDate[:,i]
    elif i == 8:
        df_filtered['band8A'] = dataByDate[:,i]
    else:
        df_filtered['band'+str(i-1)] = dataByDate[:,i]
"""
# Out:
# /home/thanh/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/thanh/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/thanh/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_filtered.head(10)
# Out:
#   Date's Observation            Sentinel2_Code  Date Image  Observed TSS  \
# 0         17/03/2017  T48QUJ_20170318T033531_B    18032017       278.558
# 1         17/03/2017  T48QUJ_20170318T033531_B    18032017       128.603
# 2         17/03/2017  T48QUJ_20170318T033531_B    18032017       128.136
# 3         17/03/2017  T48QUJ_20170318T033531_B    18032017       116.209
# 4         17/03/2017  T48QUJ_20170318T033531_B    18032017        95.614
# 5         17/03/2017  T48QUJ_20170318T033531_B    18032017       139.061
# 6         17/03/2017  T48QUJ_20170318T033531_B    18032017       199.232
# 7         17/03/2017  T48QUJ_20170318T033531_B    18032017       143.726
# 8         17/03/2017  T48QUJ_20170318T033531_B    18032017       169.700
# 9         16/05/2017  T48QUJ_20170517T033541_B    17052017       733.000
#
#    Band2  Band3  Band4  Band8
# 0   1767   1818   1725   2940
# 1    742    907    865    923
# 2    720    842    821    777
# 3    785   1079   1099   1128
# ...

# %%
# Save to excel file
df_filtered.to_csv('processed_data_sen2cor.csv',index=0)
df_filtered.to_excel('processed_data_sen2cor.xlsx',index=False)
